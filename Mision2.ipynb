# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresMedina117/CursoDEEPLEARNING/blob/main/Mision2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import time
import os
from google.colab import files
import zipfile
from tensorflow.keras import regularizers

# %%
print("hola caracola")
# Out:
# hola caracola
